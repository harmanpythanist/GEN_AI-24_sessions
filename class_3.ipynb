# %% [markdown]
# ## Functions

# %%
in1 = int(input('Write marks of philosophy: '))
in2 = int(input('Write marks of ICT: '))
in3 = int(input('Write marks of management: '))
in4 = int(input('Write marks of Quran: '))
in5 = int(input('Write marks of English: '))
in6 = int(input('Write marks of Math: '))

total_marks = 600

obtain_marks = in1 + in2 + in3 + in4 + in5 + in6

average = (obtain_marks / total_marks) * 100
print('==========================')
print('Average: ', average)
# Out:
# Write marks of philosophy:  2
# Write marks of ICT:  2
# Write marks of management:  2
# Write marks of Quran:  2
# Write marks of English:  2
# Write marks of Math:  2
# ...
# Average:  2.0

# %%
in1 = int(input('Write marks of philosophy: '))
in2 = int(input('Write marks of ICT: '))
in3 = int(input('Write marks of management: '))
in4 = int(input('Write marks of Quran: '))
in5 = int(input('Write marks of English: '))
in6 = int(input('Write marks of Math: '))

total_marks = 600

obtain_marks = in1 + in2 + in3 + in4 + in5 + in6

average = (obtain_marks / total_marks) * 100
print('==========================')
print('Average: ', average)

# %%
def average():
    in1 = int(input('Write marks of philosophy: '))
    in2 = int(input('Write marks of ICT: '))
    in3 = int(input('Write marks of management: '))
    in4 = int(input('Write marks of Quran: '))
    in5 = int(input('Write marks of English: '))
    in6 = int(input('Write marks of Math: '))
    
    total_marks = 600
    
    obtain_marks = in1 + in2 + in3 + in4 + in5 + in6
    
    average = (obtain_marks / total_marks) * 100
    print('==========================')
    print('Average: ', average)

# %%
average()
# Out:
# Write marks of philosophy:  45
# Write marks of ICT:  65
# Write marks of management:  65
# Write marks of Quran:  45
# Write marks of English:  78
# Write marks of Math:  90
# ...
# Average:  64.66666666666666

# %%
average()
# Out:
# Write marks of philosophy:  56
# Write marks of ICT:  76
# Write marks of management:  89
# Write marks of Quran:  76
# Write marks of English:  89
# Write marks of Math:  87
# ...
# Average:  78.83333333333333

# %%
name = 'ali'
age = 25

print(name + ' is a good boy')
print('his age is ' +  str(age))
# Out:
# ali is a good boy
# his age is 25

# %% [markdown]
# # MACHINE LEARNING MODELS

# %%
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# %%
data = pd.read_csv('D://Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
features = data[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
labels = data["Species"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 features = data[["Sepal length","Sepal width","Petal length","Petal Width"]]
#       2 labels = data["Species"]
#
# File D:\anaconda\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File D:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
features = data[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]

# %%
labels = data["Species"]

# %% [markdown]
# #Initializing ML Model

# %%
model= KNeighborsClassifier()

# %%
model.fit(features,labels)
# Out:
# KNeighborsClassifier()

# %%
model.predict([[10,5,2,7]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-virginica'], dtype=object)

# %%
model.predict([[3,1,2,1.3]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)

# %%
from sklearn.linear_model import LinearRegression as lr

# %%
import pandas as pd

# %%
file=pd.read_excel("D://marks_data.xlsx")

# %%
feature = file[["study_hours","previous_grade","performance_of_10"]]

# %%
labels = file ['marks_scored']

# %%
model=lr()

# %% [markdown]
# #Initialize

# %%
model.fit(feature,labels)
# Out:
# LinearRegression()

# %%
model.predict([[4,0.7,8]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.85618313])

# %%
model.predict([[4,0.7,5]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.63196675])

# %%
model.predict([[5,0.7,5]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.64786204])

# %%
model_new= KNeighborsClassifier()

# %%
final_lable = labels * 100
model_new.fit(feature,labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 final_lable = labels * 100
# ----> 2 model_new.fit(feature,labels)
#
# File D:\anaconda\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File D:\anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:238, in KNeighborsClassifier.fit(self, X, y)
#     216 @_fit_context(
#     217     # KNeighborsClassifier.metric is not validated yet
#     218     prefer_skip_nested_validation=False
#     219 )
#     220 def fit(self, X, y):
# ...

# %%
model_new.predict([[5,0.7,7]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 model_new.predict([[5,0.7,7]])
#
# File D:\anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:254, in KNeighborsClassifier.predict(self, X)
#     240 def predict(self, X):
#     241     """Predict the class labels for the provided data.
#     242
#     243     Parameters
#    (...)
#     252         Class labels for each data sample.
#     253     """
# --> 254     check_is_fitted(self, "_fit_method")
#     255     if self.weights == "uniform":
#     256         if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     257             X, self._fit_X, self.metric
#     258         ):
#
# File D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1622, in check_is_fitted(estimator, attributes, msg, all_or_any)
# ...

# %%
feature
# Out:
#    study_hours  previous_grade  performance_of_10
# 0            3            0.72                7.2
# 1            1            0.69                6.3
# 2            5            0.87                8.6
# 3            2            0.75                7.9
# 4            3            0.78                7.9
# 5            5            0.85                9.2
# 6            4            0.82                9.1
# 7            2            0.71                7.3

# %%
# Out:
# 0    75.0
# 1    72.0
# 2    84.0
# 3    78.0
# 4    76.0
# 5    94.0
# 6    89.0
# 7    78.0
# Name: marks_scored, dtype: float64
